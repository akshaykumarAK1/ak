# %%
import matplotlib.pyplot as plt 
import tensorflow as tf 
from keras.utils import to_categorical 
layers = tf.keras.layers 
 
from keras.datasets import mnist 
(x_train, y_train), (x_test, y_test) = mnist.load_data() 
 
x_train = x_train.astype('float32') / 255.0 
x_test = x_test.astype('float32') / 255.0 
 
# one-hot encode the labels 
y_train = to_categorical(y_train, 10) 
y_test = to_categorical(y_test, 10) 
 
plt.figure(figsize=(10,8)) 
for i in range(1, 15): 
    # image in ith position of grid 
    plt.subplot(5, 5, i) 
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray')) 
plt.show() 
 
model = tf.keras.Sequential() 
model.add(layers.Flatten()) 
model.add(layers.Dense(5, activation='sigmoid')) 
model.add(layers.Dense(10, activation='softmax')) 
 
model.compile(optimizer='adam', loss='categorical_crossentropy', 
metrics=['accuracy']) 
model.fit(x_train, y_train, epochs=10, batch_size=32, 
validation_data=(x_test, y_test)) 
 
loss, accuracy = model.evaluate(x_test, y_test) 
print('\n\nTest loss', loss) 
print('Test accuracy', accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 8s 1us/step
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.4999 - loss: 1.7455 - val_accuracy: 0.7740 - val_loss: 1.0139
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7952 - loss: 0.9213 - val_accuracy: 0.8272 - val_loss: 0.7299
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8300 - loss: 0.6938 - val_accuracy: 0.8406 - val_loss: 0.6175
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8438 - loss: 0.6024 - val_accuracy: 0.8501 - val_loss: 0.5604
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8545 - loss: 0.5492 - val_accuracy: 0.8564 - val_loss: 0.5228
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8599 - loss: 0.5171 - val_accuracy: 0.8620 - val_loss: 0.4972
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8655 - loss: 0.4897 - val_accuracy: 0.8625 - val_loss: 0.4836
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8696 - loss: 0.4732 - val_accuracy: 0.8701 - val_loss: 0.4676
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8741 - loss: 0.4496 - val_accuracy: 0.8723 - val_loss: 0.4584
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8757 - loss: 0.4439 - val_accuracy: 0.8734 - val_loss: 0.4466
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8586 - loss: 0.4842
#
#
# Test loss 0.4465755820274353
# Test accuracy 0.8733999729156494

# %%
import matplotlib.pyplot as m
from keras.utils import to_categorical
from keras.datasets import mnist
import tensorflow as tf
layers=tf.keras.layers
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train.astype('float32')/255.0
x_test=x_test.astype('float32')/255.0

y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

m.figure(figsize=(10,8))
for i in range(1,15):
    m.subplot(5,5,i)
    m.imshow(x_train[i],cmap=('gray'))
m.show()
model=tf.keras.Sequential()
model.add(layers.Flatten())
model.add(layers.Dense(5,activation='sigmoid'))
model.add(layers.Dense(10,activation='softmax'))
                                   
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=10)#,batch_size=32,validation_data=(x_test,y_test))
loss,accuracy=model.evaluate(x_test,y_test)
print('loss' ,loss)
print('\n accuracy \n',accuracy)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5337 - loss: 1.7345
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8254 - loss: 0.8419
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8454 - loss: 0.6266
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8563 - loss: 0.5460
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8611 - loss: 0.5126
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8675 - loss: 0.4771
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8712 - loss: 0.4603
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8769 - loss: 0.4469
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8754 - loss: 0.4461
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8767 - loss: 0.4390
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8613 - loss: 0.4843
# loss 0.4370213747024536
#
#  accuracy
#  0.8765000104904175

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
t = pd.read_csv('temper.csv', parse_dates=['day'], index_col='day')
a = t.plot(color='k', linewidth=1)
plt.xticks(rotation=25)
a.set_ylabel('Temp')
plt.xlabel('Date')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_3636\523682547.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   t = pd.read_csv('temper.csv', parse_dates=['day'], index_col='day')

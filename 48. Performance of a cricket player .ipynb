# %%
#a. Preprocessing 
 
import pandas as p 
da=p.read_csv("dhoni.csv") 
da.info() 
 
#PRE_PROCESSING 
miss=da.isna().sum() 
print("\nMissing Values:\n",miss) 
da.dropna(inplace=True) 
print("\nMissing Values:\n",da.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           15 non-null     int64
#  1   Matches        15 non-null     int64
#  2   Innings        15 non-null     int64
#  3   N.O.           15 non-null     int64
#  4   Runs           15 non-null     int64
#  5   Highest Score  15 non-null     int64
#  6   Average        15 non-null     float64
#  7   Strike Rate    15 non-null     float64
#  8   100            15 non-null     int64
#  9   50             15 non-null     int64
#  10  Fours          15 non-null     int64
#  11  Sixes          15 non-null     int64
#  12  Catches Taken  15 non-null     int64
#  13  Stumpings      15 non-null     int64
# dtypes: float64(2), int64(12)
# memory usage: 1.8 KB
#
# Missing Values:
#  Year             0
# Matches          0
# Innings          0
# N.O.             0
# Runs             0
# Highest Score    0
# Average          0
# Strike Rate      0
# 100              0
# 50               0
# Fours            0
# Sixes            0
# Catches Taken    0
# Stumpings        0
# dtype: int64
#
# Missing Values:
#  Year             0
# Matches          0
# Innings          0
# N.O.             0
# Runs             0
# Highest Score    0
# Average          0
# Strike Rate      0
# 100              0
# 50               0
# Fours            0
# Sixes            0
# Catches Taken    0
# Stumpings        0
# dtype: int64

# %%
 
##b. Exploration 

import matplotlib.pyplot as m 
import seaborn as s 
m.figure(figsize=(18,10)) 
s.histplot(da['Runs'], bins=15, kde=True) 
m.title('Distribution of Runs Scored') 
m.show() 
m.figure(figsize=(18,10)) 
s.barplot(data=da,x='Year',y='Runs',palette='viridis') 
m.title('Batting Scores Over the Years') 
m.xlabel('Year');m.ylabel('Runs') 
m.xticks(rotation=45);m.show() 
m.figure(figsize=(18,10)) 
s.heatmap(data=da.corr(),annot=True,cmap='crest') 
m.title("Heatmap on DHONI's stats") 
m.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2564\512302882.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   s.barplot(data=da,x='Year',y='Runs',palette='viridis')

# %%
#c. Splitting 
 

from sklearn.model_selection import train_test_split 
 
X = da.drop('Average', axis=1)   
y = da['Average'] 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
random_state=42) 
print("Train set:", X_train.shape, y_train.shape) 
print("Test set:", X_test.shape, y_test.shape)
# Out:
# Train set: (10, 13) (10,)
# Test set: (5, 13) (5,)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Open and read the text file
#with open("akshay.txt", "r") as f:
f=open('akshay.txt')
text = f.read()

# Define stopwords
stop_w = set(STOPWORDS)

# Generate the word cloud
wc = WordCloud(
    width=800,
    height=800,
    background_color='black',
    colormap='plasma',
    stopwords=stop_w,
    min_font_size=1
).generate(text)

# Display the word cloud
plt.figure(figsize=(5,5), facecolor=None)
plt.imshow(wc)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
import matplotlib.pyplot as m
from wordcloud import WordCloud,STOPWORDS

f=open('akshay.txt')
w=f.read()

stop_w=set(STOPWORDS)

wc=WordCloud(
    width=800,
    height=800,
    background_color='black',
    colormap='plasma',
    stopwords=stop_w,
    min_font_size=1
).generate(w)
m.figure(figsize=(10,5),facecolor=None)
m.imshow(wc)
m.axis('off')
m.show()

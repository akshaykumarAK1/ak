# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Load the dataset
data = pd.read_csv("Mall_Customers.csv")

# Extract features (Annual Income and Spending Score)
x = data.iloc[:, [3, 4]].values

# Elbow method to determine the optimal number of clusters
inertia = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(x)
    inertia.append(kmeans.inertia_)

# Plot the elbow method
plt.plot(range(1, 11), inertia, marker='o')
plt.title("Elbow Method")
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# Apply k-means clustering with the optimal number of clusters (assumed 5 here)
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42, n_init=10)
y_pred = kmeans.fit_predict(x)

# Plot the clusters
plt.scatter(x[y_pred == 0, 0], x[y_pred == 0, 1], s=100, c='blue', label='Cluster 1')
plt.scatter(x[y_pred == 1, 0], x[y_pred == 1, 1], s=100, c='green', label='Cluster 2')
plt.scatter(x[y_pred == 2, 0], x[y_pred == 2, 1], s=100, c='lime', label='Cluster 3')
plt.scatter(x[y_pred == 3, 0], x[y_pred == 3, 1], s=100, c= 'red', label='Cluster 4')
plt.scatter(x[y_pred == 4, 0], x[y_pred == 4, 1], s=100, c='black', label='Cluster 5')

# Plot cluster centers
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids', marker='X')

plt.title("Clusters of Customers")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score (1-100)")
plt.legend()
plt.show()

# %%
import pandas as p
import matplotlib.pyplot as m
from sklearn.cluster import KMeans

da=p.read_csv("Mall_Customers.csv")
x=da.iloc[:,[3,4]].values

inertia=[]
for i in range(1,11):
    #kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
    mod=KMeans(n_clusters=i, init='k-means++', random_state=42 ,n_init=10)
    mod.fit(x)
    inertia.append(mod.inertia_)
m.plot(range(1,11),inertia,marker='^')
m.title('eblow method')
m.show()

kmeans=KMeans(n_clusters=5,init='k-means++',random_state=42,n_init=10)
y_pred=kmeans.fit_predict(x)

m.scatter(x[y_pred==0,0],x[y_pred==0,1],s=100,c='blue',label='cluster 1')
m.scatter(x[y_pred==1,0],x[y_pred==1,1],s=100,c='lime',label='cluster 2')
m.scatter(x[y_pred==2,0],x[y_pred==2,1],s=100,c='green',label='cluster 3')
m.scatter(x[y_pred==3,0],x[y_pred==3,1],s=100,c='k',label='cluster 4')
m.scatter(x[y_pred==4,0],x[y_pred==4,1],s=100,c='red',label='cluster 5')
#m.scatter(kmeans.cluster_centers_[:0],mod1.cluster_centers[:1],s=100,c='yellow',label='setroid',marker='x')
m.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='yellow', label='Centroids', marker='X')

m.title('cluster')
m.show()

# %%
import pandas as p
import matplotlib.pyplot as m
df=p.read_csv('DailyDelhiClimateTest.csv')
x=df.meantemp
y=df.day
m.figure(figsize=(18,10))
m.scatter(x,y,label="values of x & y")
m.xlabel("")
m.ylabel("date")
m.title("Scatter plot")
m.show()

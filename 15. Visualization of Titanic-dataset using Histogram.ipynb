# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv('tested - Copy.csv')
age_survived = data[data['Survived'] == 1]['Age']
age_not_survived = data[data['Survived'] == 0]['Age']
plt.hist(age_survived, color='g', label='Survived')
plt.hist(age_not_survived, color='k', alpha=0.5,label='Not Survived')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Survived and Not Survived Passengers')
plt.legend()
plt.show()

# %%
import pandas as p
import matplotlib.pyplot as m

da=p.read_csv('tested - Copy.csv')
sur=da[da['Survived']==1]['Age']
nosur=da[da['Survived']==0]['Age']
m.hist(sur,color='k',label='Survived')
m.hist(nosur,color='g',alpha=0.5,label='Not survived')
m.legend()
m.show()
